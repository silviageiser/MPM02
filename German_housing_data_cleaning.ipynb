# %%
import pandas as pd
import numpy as np
data = pd.read_csv('C:/Users/silvi/OneDrive - Hochschule Luzern/IDS_Master/HS20/MPM02 - Machine Learning/MPM02 - Group Project/germany_housing_original_data.csv')

# %%
data.head(18)
# Out:
#     Unnamed: 0      Price               Type  Living_space     Lot  \
# 0            0   498000.0  Multiple dwelling        106.00   229.0
# 1            1   495000.0  Mid-terrace house        140.93   517.0
# 2            2   749000.0          Farmhouse        162.89    82.0
# 3            3   259000.0          Farmhouse        140.00   814.0
# 4            4   469000.0  Multiple dwelling        115.00   244.0
# 5            5  1400000.0  Mid-terrace house        310.00   860.0
# 6            6  3500000.0             Duplex        502.00  5300.0
# 7            7   630000.0             Duplex        263.00   406.0
# 8            8   364000.0             Duplex        227.00   973.0
# 9            9  1900000.0             Duplex        787.00   933.0
# 10          10  1750000.0  Mid-terrace house        210.00  1460.0
# 11          11   470000.0             Duplex        268.00  1511.0
# 12          12   475000.0    Single dwelling        124.00   258.0
# ...

# %%
data['Energy_source'].unique()
# Out:
# array(['natural gas', nan, 'district heating', 'electricity', 'oil',
#        'renewable energies', 'wood', 'coal'], dtype=object)

# %%
data = data.drop(['Unnamed: 0', 'Usable_area', 'Free_of_Relation', 'Energy_certificate','Energy_certificate_type','Energy_consumption'], axis=1)

# %%
data['Energy_source'] = data['Energy_source'].replace({' Gas ' : 'natural gas', " Öl " : 'oil', ' Fernwärme, Bioenergie ' : 'district heating', ' Gas, Fernwärme-Dampf ' : 'natural gas', ' Solar, Öl ' : 'renewable energies', ' Solar, Holz-Hackschnitzel ' : 'renewable energies', ' Erdgas schwer ' : 'natural gas', ' Solar, Holzpellets, Holz ' : 'renewable energies', ' Erdwärme ' : 'renewable energies', ' Holzpellets, Strom ' : 'wood', ' Holz ' : 'wood', ' Solar, Erdgas schwer ' : 'renewable energies', ' Solar, Öl, Strom, KWK fossil ' : 'renewable energies', ' Umweltwärme ' : 'renewable energies', ' KWK erneuerbar ' : 'renewable energies', ' Bioenergie ' : 'renewable energies', ' Solar ' : 'renewable energies', ' Gas, Strom ' : 'natural gas', ' Nahwärme ' : 'renewable energies', ' Gas, Holz ' : 'natural gas', ' Fernwärme-Dampf ' : 'district heating', ' Solar, Holzpellets, Öl ' : 'renewable energies', ' Erdgas schwer, Bioenergie ' : 'natural gas', ' Wärmelieferung ' : 'district heating', ' Öl, Bioenergie ' : 'oil', ' Gas, Öl, Strom ' : 'natural gas', ' Kohle, Holz ' : 'coal', ' Holz, Bioenergie ' : 'wood', ' Holzpellets, Holz ' : 'wood', ' Strom, Umweltwärme ' : 'electricity', ' Strom ' : 'electricity', ' Erdwärme, Holzpellets ' : 'renewable energies', ' Fernwärme ' : 'district heating', ' Holzpellets ' : 'wood', ' Gas, Öl ' :
wärme, Strom ' : 'renewable energies', ' Strom, Flüssiggas ' : 'electricity', ' Solar, Bioenergie ' : 'renewable energies', ' Gas, Öl, Kohle, Holz ' : 'natural gas', ' Gas, Strom, Holz ' : 'natural gas', ' Gas, Öl, Holz ' : 'natural gas', ' Gas, Wasserenergie ' : 'natural gas', ' Erdwärme, Solar, Holzpellets, Holz ' : 'district heating', ' Solar, Holzpellets, Strom ' : 'renewable energies'}, inplace=False)

# %%
data['Condition'] = data['Condition'].replace({ 'modernized' : 'refurbished', 'renovated': 'refurbished', 'by arrangement': 'NaN'}, inplace=False)

# %%
data['Condition'] = data['Condition'].replace('NaN',np.NaN)

# %%
data['Condition'].value_counts()
# Out:
# refurbished                             6779
# dilapidated                             1167
# maintained                              1069
# fixer-upper                              588
# first occupation after refurbishment     461
# first occupation                          97
# as new                                    12
# Name: Condition, dtype: int64

# %%
data['Energy_source'].value_counts()
# Out:
# natural gas           4993
# oil                   2694
# electricity            610
# renewable energies     466
# wood                   309
# district heating       211
# coal                    42
# Name: Energy_source, dtype: int64

# %%
data_price_sorted = data.sort_values("Price", axis = 0, ascending = True, inplace = False, na_position ='first')

# %%
data_renovation_sorted = data.sort_values("Year_renovated", axis = 0, ascending = False, inplace = False, na_position ='last')

# %%
data_living_sorted = data.sort_values("Living_space", axis = 0, ascending = True, inplace = False, na_position ='last')

# %%
data_living_sorted.head()
# Out:
#         Price              Type  Living_space     Lot  Rooms  Bedrooms  \
# 5400  33500.0               NaN         16.32     0.0    2.0       1.0
# 7271  46000.0               NaN         20.00   150.0    2.0       1.0
# 9669  19900.0  Special property         20.00   750.0    1.0       NaN
# 4654  41000.0          Bungalow         20.00     0.0    2.0       1.0
# 4243  90000.0            Duplex         21.30  1544.0    1.0       1.0
#
#       Bathrooms  Floors Year_built Furnishing_quality  Year_renovated  \
# 5400        0.0     0.0        NaN                NaN          2019.0
# 7271        1.0     1.0       2020                NaN             NaN
# 9669        1.0     NaN       2008             normal             NaN
# 4654        NaN     1.0        NaN            refined             NaN
# 4243        1.0     4.0       1971             normal             NaN
#
#         Condition          Heating Energy_source Energy_efficiency_class  \
# ...

# %%
data['Energy_efficiency_class'] = data['Energy_efficiency_class'].str.strip(' ')

# %%
data = data.drop([343,9955,8176,7737], axis= 0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10552 entries, 0 to 10551
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               10552 non-null  int64
#  1   Price                    10552 non-null  float64
#  2   Type                     10150 non-null  object
#  3   Living_space             10552 non-null  float64
#  4   Lot                      10552 non-null  float64
#  5   Usable_area              5568 non-null   float64
#  6   Free_of_Relation         6983 non-null   object
#  7   Rooms                    10552 non-null  float64
#  8   Bedrooms                 6878 non-null   float64
#  9   Bathrooms                8751 non-null   float64
#  10  Floors                   7888 non-null   float64
#  11  Year_built               9858 non-null   float64
#  12  Furnishing_quality       7826 non-null   object
# ...

# %%
data.to_csv(r'C:/Users/silvi/OneDrive - Hochschule Luzern/IDS_Master/HS20/MPM02 - Machine Learning/MPM02 - Group Project/Group_project/germany_housing_cleaned.csv', index=False)

# %%
data.head()
# Out:
#       Price               Type  Living_space    Lot  Rooms  Bedrooms  \
# 0  498000.0  Multiple dwelling        106.00  229.0    5.5       3.0
# 1  495000.0  Mid-terrace house        140.93  517.0    6.0       3.0
# 2  749000.0          Farmhouse        162.89   82.0    5.0       3.0
# 3  259000.0          Farmhouse        140.00  814.0    4.0       NaN
# 4  469000.0  Multiple dwelling        115.00  244.0    4.5       2.0
#
#    Bathrooms  Floors Year_built Furnishing_quality  Year_renovated  \
# 0        1.0     2.0       2005             normal             NaN
# 1        2.0     NaN       1994              basic             NaN
# 2        2.0     4.0       2013                NaN             NaN
# 3        2.0     2.0       1900              basic          2000.0
# 4        1.0     NaN       1968            refined          2019.0
#
#      Condition          Heating     Energy_source Energy_efficiency_class  \
# ...

# %%
data.describe()
# Out:
#               Price  Living_space            Lot         Rooms     Bedrooms  \
# count  1.051200e+04  10512.000000   10512.000000  10512.000000  6858.000000
# mean   5.583670e+05    216.357449    1486.617467      7.378472     4.164188
# std    6.082279e+05    171.879911    8590.757566      5.364841     2.560828
# min    1.000000e+04      1.000000       0.000000      1.000000     0.000000
# 25%    2.500000e+05    130.000000     370.000000      5.000000     3.000000
# 50%    4.100000e+05    176.030000     655.500000      6.000000     4.000000
# 75%    6.590000e+05    250.000000    1045.000000      8.000000     5.000000
# max    1.300000e+07   5600.000000  547087.000000    170.000000    61.000000
#
#          Bathrooms       Floors  Year_renovated      Garages
# count  8723.000000  7858.000000     5327.000000  8564.000000
# mean      2.307348     2.283278     2010.677117     2.689981
# std       1.737701     0.820340       10.185057     3.174513
# ...

# %%
data_renovation_sorted.head(10)
# Out:
#           Price               Type  Living_space     Lot  Rooms  Bedrooms  \
# 10548  449000.0  Mid-terrace house        222.00  4000.0    6.0       5.0
# 6511   729000.0  Mid-terrace house        290.00  1703.0   11.0       NaN
# 918    685000.0    Single dwelling        153.73   324.0    7.0       4.0
# 5795   420000.0  Mid-terrace house        190.00  1650.0    5.0       3.0
# 911    449000.0  Mid-terrace house        141.29   586.0    6.0       5.0
# 5814   579000.0  Mid-terrace house        186.00   677.0    5.0       4.0
# 900    299000.0  Mid-terrace house        120.00   752.0    5.0       NaN
# 5839   175000.0             Duplex        185.00  1108.0    9.0       6.0
# 5848   329000.0    Single dwelling        113.30   316.0    4.0       3.0
# 872    418000.0          Farmhouse        116.20   138.0    5.0       3.0
#
#        Bathrooms  Floors  Year_built Furnishing_quality  Year_renovated  \
# 10548        3.0     1.0      2017.0                NaN          2020.0
# ...
